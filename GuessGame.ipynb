# %%
import random

process=True
no=random.randint(0,20)
chance=0
name=input("hello there! what's your name\n")
print("Hello",name,"I am going to guess a no b/w 0 to 20\n")
print("Five chances allowed")

while process:
    choice =input("Guess a number\n")
    if int(choice) == no:
        print("Well Done! You guessed it.")
        print("Would you like to play again?",name,"?","\n 1.Yes \n 2. No")
        option= input()
    if choice == str(1):
        chance =0
        pass
    if choice == str(2):
        exit("thanks for playing")
    elif int(choice)>no:
        print("your no is too high")
        chance=chance+1
    elif int(choice)<no:
        print("Your no is too low")
        chance=chance+1
    else:
        pass
    if int(choice)<=5:
        print("you have reached maximum no of chances")
        print("the no i was thinking was",no)
        exit()
# Out:
# hello there! what's your name
# xyz
# Hello xyz I am going to guess a no b/w 0 to 20
#
# Five chances allowed
# Guess a number
# 15
# your no is too high
# Guess a number
# 13
# your no is too high
# Guess a number
# 12
# your no is too high
# Guess a number
# 10
# your no is too high
# Guess a number
# 18
# your no is too high
# Guess a number
# 5
# your no is too high
# you have reached maximum no of chances
# the no i was thinking was 4
# Guess a number
# 8
# your no is too high
# Guess a number
# 6
# your no is too high
# Guess a number
# 5
# your no is too high
# you have reached maximum no of chances
# the no i was thinking was 4
# Guess a number
# 8
# your no is too high
# Guess a number
# 6
# your no is too high
# Guess a number
# 7
# your no is too high
# Guess a number
# 9
# your no is too high
# Guess a number
# 4
# Well Done! You guessed it.
# Would you like to play again? xyz ?
#  1.Yes
#  2. No
# 2
# you have reached maximum no of chances
# the no i was thinking was 4
